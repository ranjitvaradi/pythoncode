# %%
NUMBER 1:
Descriptive Analytics for Numerical Columns
●	Objective: To compute and analyze basic statistical measures for numerical columns in the dataset.
●	Steps:
	Load the dataset into a data analysis tool or programming environment (e.g., Python with pandas library).
	Identify numerical columns in the dataset.
	Calculate the mean, median, mode, and standard deviation for these columns.
	Provide a brief interpretation of these statistics.

# %%
#Importing numpy,pandas,random,scipy libraries

import numpy as np
import pandas as pd
import random
from scipy import stats

# %%
df1=pd.read_csv("sales_data_with_discounts.csv") #Reading data from input file in pandas library.
nc=df1.select_dtypes(include=['int','float']).columns.tolist() #List of Numerical data columns in the data set
nc
# Out:
# ['Volume',
#  'Avg Price',
#  'Total Sales Value',
#  'Discount Rate (%)',
#  'Discount Amount',
#  'Net Sales Value']

# %%
round(df1[df1.select_dtypes(include=['int','float']).columns.tolist()].describe(),2) #Descriptive Analytics for Numerical Columns
# Out:
#        Volume  Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.00     450.00             450.00             450.00
# mean     5.07   10453.43           33812.84              15.16
# std      4.23   18079.90           50535.07               4.22
# min      1.00     290.00             400.00               5.01
# 25%      3.00     465.00            2700.00              13.97
# 50%      4.00    1450.00            5700.00              16.58
# 75%      6.00   10100.00           53200.00              18.11
# max     31.00   60100.00          196400.00              19.99
#
#        Discount Amount  Net Sales Value
# count           450.00           450.00
# mean           3346.50         30466.34
# std            4509.90         46358.66
# min              69.18           326.97
# 25%             460.46          2202.21
# 50%             988.93          4677.79
# 75%            5316.50         47847.91
# max           25738.02        179507.48

# %%
interpretation:
The total data points are 450.
The mean,std,min,max and inter quartile range calculated above.
There are outlayes and large scale anamalies present data by observing above values.

# %%
NUMBER 02:
Data Visualization:
●	Objective: To visualize the distribution and relationship of numerical and categorical variables in the dataset.
●	Histograms:
	Plot histograms for each numerical column.
	Analyze the distribution (e.g., skewness, presence of outliers) and provide inferences.

# %%
import matplotlib.pyplot as plt #Importing required libraries and reading data from the input file
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
df1=pd.read_csv("sales_data_with_discounts.csv")

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 4)) #Deviding the plot in to subplots for better analysis
axs[0].hist(df1["Volume"], bins=30, alpha=0.7,edgecolor='black') #at axis 0 histogram and axis 1 sns Kde bins are 30 , alpha is transperency of bars.
axs[0].set_title('Histogram of Sales Data for Volume') #Title
sns.histplot(df1["Volume"], bins=30, alpha=0.7, color='green',kde=True, ax=axs[1]) #for KDE chart
axs[0].set_xlabel('Volume') #Labels at x and y axis
axs[0].set_ylabel('count')
axs[1].set_title('Histogram of Sales Data for Volume With KDE')  #Title
plt.tight_layout()# This will adjust the space between charts so that they will not coinside.
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df1['Volume'].skew(),df1['Volume'].kurtosis()  #calculating skew ness and kurtosis
# Out:
# (2.731723626557714, 10.258547145181762)

# %%
Inferences:
The Volume distribution is skewed towards right side and the skewness is +ve and it is 2.73.
The central tendency of histogram is distributed at 5 and the maximum value is at 4.
The histogram is narrower and it  suggests lower variability or more concentrated data.The kurtosis value is positive and it is 10.25. 
As there isolated bars that indicates the outlayers
The histogram is unimodal as there is single peak at 4 means at 4 maximum value is recorded.
The most of the volume is in between the values 3 and 6.

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 4))
axs[0].hist(df1["Avg Price"], bins=30, alpha=0.7,edgecolor='black')
axs[0].set_title('Histogram of Sales Data for Avg Price')
axs[0].set_xlabel('Avg Price')
axs[0].set_ylabel('count')
sns.histplot(df1["Avg Price"], bins=30, alpha=0.7,color='green',kde=True, ax=axs[1])
axs[1].set_title('Histogram of Sales Data for Avg Price With KDE')
plt.tight_layout()
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df1['Avg Price'].skew(),df1['Avg Price'].kurtosis()
# Out:
# (1.9088730767759727, 2.07565498004372)

# %%
Inferences:
The distribution is skewed towards right side and the skewness is +ve and it is 1.9.
The central tendency of histogram is distributed at initial values.
The histogram is not narrower and it suggests higher variability.The kurtosis value is positive and it is 2. 
As there are isolated bars that indicates the outlayers in between 50000 and 60000.
The histogram is bimodal as there is double peak at 5000 and 55000 but at 5000 maximum value is recorded.
The most of the volume is in between the values 0 and 5000.

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 4))
axs[0].hist(df1["Total Sales Value"], bins=30, alpha=0.7,edgecolor='black')
axs[0].set_title('Histogram of Sales Data for Total Sales Value')
axs[0].set_xlabel('Total Sales Value')
axs[0].set_ylabel('Count')
sns.histplot(df1["Total Sales Value"], bins=30, alpha=0.7,color='green',kde=True, ax=axs[1])
axs[1].set_title('Histogram of Sales Data for Total Sales Value With KDE')
plt.tight_layout()
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df1['Total Sales Value'].skew(),df1['Total Sales Value'].kurtosis()
# Out:
# (1.5347293238977937, 1.0249161068455352)

# %%
Inferences:
The distribution is skewed towards right side and the skewness is +ve and it is 1.5.
The central tendency of histogram is distributed at initial values.
The histogram is not narrower and it suggests higher variability.The kurtosis value is positive and it is 1.02. 
As there are isolated bars that indicates the outlayers in between 75 thousand and 2 lakhs.
The histogram is unimodal as there is a peak at 5000  at 5000 maximum sales value is recorded.
The most of the sales is in between the values 0 and 25000.

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 4))
axs[0].hist(df1["Discount Rate (%)"], bins=30, alpha=0.7,edgecolor='black')
axs[0].set_title('Histogram of Sales Data for Discount Rate (%)')
axs[0].set_xlabel('Discount Rate (%)')
axs[0].set_ylabel('Count')
sns.histplot(df1["Discount Rate (%)"], bins=30, alpha=0.7,color='green',kde=True, ax=axs[1])
axs[1].set_title('Histogram of Sales Data for Discount Rate (%) With KDE')
plt.tight_layout()
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df1['Discount Rate (%)'].skew(),df1['Discount Rate (%)'].kurtosis()
# Out:
# (-1.0622943696988827, -0.1785407468981699)

# %%
Inferences:
The distribution is skewed towards left side and the skewness is -ve and it is -1.06.
The central tendency of histogram is distributed at final  values that is between 16 and 20.
The histogram is broader and it suggests higher variability.The kurtosis value is negative and it is 1. 
As there are no isolated bars that indicates no outlayers.
At 18% discount maximum sales made. The histogram is bimodal as there are peaks at 8 and 18 and  at 18 maximum sales value is recorded
The most of the sales is in between the values 15 and 20.

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 4))
axs[0].hist(df1["Discount Amount"], bins=30, alpha=0.7,edgecolor='black')
axs[0].set_title('Histogram of Sales Data for Discount Amount')
axs[0].set_xlabel('Discount Amount')
axs[0].set_ylabel('Count')
sns.histplot(df1["Discount Amount"], bins=30, alpha=0.7,kde=True,color='green', ax=axs[1])
axs[1].set_title('Histogram of Sales Data for Discount Amount With KDE')
plt.tight_layout()
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df1['Discount Amount'].skew(),df1['Discount Amount'].kurtosis()
# Out:
# (1.9130377339538265, 3.8311859719016317)

# %%
Inferences:
The distribution is skewed towards right side and the skewness is +ve and it is 1.9.
The central tendency of histogram is distributed at initial values.
The histogram is narrower and it suggests less variability.The kurtosis value is positive and it is 3.83. 
As there are isolated bars that indicates the outlayers in between 20 thousand and 25 Thousand.
The histogram is unimodal as there is a peak at 1000 discount amount is more at initial values and it decreases as the amount increases.
The most of the amount is in between the values 0 and 5000.

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 4))
axs[0].hist(df1["Net Sales Value"], bins=30,edgecolor='black')
axs[0].set_title('Histogram of Sales Data for Net Sales Value')
axs[0].set_xlabel('Net Sales Value')
axs[0].set_ylabel('Count')
sns.histplot(df1["Net Sales Value"], bins=30,kde=True,color='green', ax=axs[1])
axs[1].set_title('Histogram of Sales Data for Net Sales Value With KDE')
plt.tight_layout()
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df1['Net Sales Value'].skew(),df1['Net Sales Value'].kurtosis()
# Out:
# (1.5408217575344376, 1.0124678624199062)

# %%
Inferences:
The distribution is skewed towards right side and the skewness is +ve and it is 1.5.
The Net sales are high at 5000 frequency.The central tendency of histogram is distributed at initial values.
The histogram is narrower and it suggests low variability.The kurtosis value is positive and it is 1.012. 
As there are isolated bars that indicates the outlayers in between 125 thousand and 175 thousand.
The histogram is unimodal as there is a peak at 5000 and at 5000 maximum sales value is recorded.
The most of the sales is in between the values 0 and 25000.
